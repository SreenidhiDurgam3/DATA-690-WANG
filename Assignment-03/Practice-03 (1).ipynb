# %%
from random import randint #using randint from random library
for j in range(10): 
   matr_list=[]  #an empty list to store values
   for i in range(10):
     value=randint(0,9)
     matr_list.append(value) #appending values in list
 
   res = [str(a) for a in matr_list]  #storing values of list in a matrix
   print(" " . join(res))
# Out:
# 1 2 2 6 1 7 6 7 0 5
# 7 2 2 8 3 5 5 8 8 5
# 1 1 4 1 0 6 3 6 5 0
# 7 1 3 2 8 0 2 8 7 0
# 6 0 7 4 9 4 4 8 3 9
# 0 9 6 2 0 0 2 2 7 5
# 9 3 0 6 1 8 2 3 4 6
# 0 3 2 3 6 8 8 9 1 3
# 6 8 3 1 2 2 3 9 0 2
# 3 8 5 8 2 7 5 9 6 2

# %%
from random import randint
for j in range(10):
   matr_list=[]   
   for i in range(10):
     value=randint(0,9)
     if(value%2!=0): #if condition for value is an odd number
         value='@'  #replace value with '@'
     matr_list.append(value)
 
   sarr = [str(a) for a in matr_list]
   print(" " . join(sarr))
# Out:
# @ 8 0 6 8 @ @ 2 6 4
# 2 0 8 0 6 @ @ @ @ 8
# 0 4 0 0 0 @ @ 8 0 8
# @ 2 @ @ @ @ @ 6 8 0
# 8 @ @ @ @ @ @ @ 6 @
# 2 @ @ @ 8 2 @ @ @ 8
# @ @ 2 @ @ 2 @ @ 0 @
# 8 @ @ 0 @ 8 2 @ 6 @
# @ @ @ 8 @ 4 0 @ @ 4
# @ @ @ 0 8 2 @ 8 0 @

# %%
#Calculate and Print the total of each row like the following (use "*" to separate the total from the numbers):
from random import randint
for j in range(10):
   matr_list=[]
   row_sum=0   
   for i in range(10):
     value=randint(0,9)
     matr_list.append(value)
     row_sum=row_sum+value  #row sum as sum of all values in each row
   matr_list.append("*")
   matr_list.append(row_sum)
 
   res = [str(a) for a in matr_list]
   print(" " . join(res))
# Out:
# 5 7 0 8 8 4 0 3 7 6 * 48
# 5 5 5 9 1 6 7 0 9 5 * 52
# 9 9 4 4 0 0 3 1 5 3 * 38
# 8 4 7 0 5 3 7 6 6 5 * 51
# 4 7 5 6 6 8 4 1 1 1 * 43
# 2 6 2 0 7 5 2 5 1 1 * 31
# 0 6 3 7 5 1 7 8 5 0 * 42
# 2 4 6 7 3 9 8 9 1 1 * 50
# 6 9 5 4 3 9 4 9 7 1 * 57
# 2 2 6 9 7 5 3 4 2 0 * 40

# %%
#Optional: Surround the matrix with asterisks (*) like the following:
import random as rn
print("**************************")
for i in range(10):
    print("*", end=' ') #generating the "*" pattern
    for j in range(10):
        k = rn.randint(0,9)
        print(k, end = ' ')
    print("*")
print("**************************")
# Out:
# **************************
# * 0 9 6 9 2 8 8 3 1 4 *
# * 2 9 4 1 7 1 2 7 7 3 *
# * 4 2 1 0 9 5 0 3 2 1 *
# * 5 3 4 2 4 0 2 5 2 7 *
# * 8 4 8 7 8 9 0 8 0 6 *
# * 6 0 8 6 8 5 8 5 9 2 *
# * 8 2 7 6 1 8 8 1 2 4 *
# * 8 5 2 2 5 1 2 4 4 6 *
# * 3 4 0 0 5 8 1 8 7 4 *
# * 9 6 2 8 0 5 6 4 3 0 *
# **************************

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cd381c0d-07ee-41f0-bcd2-1e4b0f99f778' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
